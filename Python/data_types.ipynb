# %% [markdown]
# # DATA TYPES:
#
# Every thing in python is an object
#
# - Memory location (id)
# - Data Type
# - Methods
# - Data/value

# %%
y = "Hello World"
print("Memory location of y ", id(y))
print("Data type" , type(y))
print("Methods of y:", "y. dot operator eg y.conjugate()")
print("Data/value of y: ", y)
# Out:
# Memory location of y  4579565424
# Data type <class 'str'>
# Methods of y: y. dot operator eg y.conjugate()
# Data/value of y:  Hello World
